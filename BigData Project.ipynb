# %%
from nltk.corpus import PlaintextCorpusReader
import os.path
import sys

basepath = os.path.dirname('/Users/TheVarunVaria/Downloads/')
corpus_root= os.path.abspath(os.path.join(basepath, "Text"))
wordlists=PlaintextCorpusReader(corpus_root, '.*')

# %%
for fileid in wordlists.fileids():
    num_char = len(wordlists.raw(fileid))
    num_words = len(wordlists.words(fileid))
    num_sents = len(wordlists.sents(fileid))
    num_vocab = len(set(w.lower() for w in wordlists.words(fileid)))
    print(round(num_words),fileid)
    if(num_words == 0):
          print("Looks like a file with no words", fileid)
    else:
          print(round(num_char/num_words),round(num_words/num_sents),round(num_vocab/num_sents),fileid)
# Out:
# 9915 a94amj.txt
# 6 14 2 a94amj.txt
# 15216 adg08hrm.txt
# 5 10 1 adg08hrm.txt
# 17048 afglmm10hrm.txt
# 5 13 2 afglmm10hrm.txt
# 8337 am79amj.txt
# 5 14 3 am79amj.txt
# 9672 ap81asq.txt
# 5 17 4 ap81asq.txt
# 4863 ar78amj.txt
# 5 12 2 ar78amj.txt
# 15647 atc05ijhrm.txt
# 5 11 1 atc05ijhrm.txt
# 10923 ay14ijbs.txt
# 6 18 3 ay14ijbs.txt
# 16473 azw06meq.txt
# 5 12 2 azw06meq.txt
# 1 b04ilr.txt
# 33 1 1 b04ilr.txt
# 814 b99ilr.txt
# 7 10 2 b99ilr.txt
# 6046 ba05joop.txt
# 9 465 136 ba05joop.txt
# 12863 bb95jibs.txt
# 6 13 2 bb95jibs.txt
# 25498 bc11amj.txt
# 5 12 1 bc11amj.txt
# 16896 bc15apjm.txt
# 5 13 2 bc15apjm.txt
# 12875 bgd05jom.txt
# 5 11 2 bgd05jom.txt
# 119 bl00aeam.txt
# 6 7 5 bl00aeam.txt
# 15517 bl00amj.txt
# 5 16 3 bl00amj.txt
# 14108 bm05jbe.txt
# 5 10 1 bm05jbe.txt
# 0 bm72rm.txt
# Looks like a file with no words bm72rm.txt
# 10339 bnk00jbr.txt
# 5 20 3 bnk00jbr.txt
# 12254 bp04beer.txt
# 4 6 1 bp04beer.txt
# 12336 bp06jms.txt
# 5 16 3 bp06jms.txt
# 8405 bp94amj.txt
# 5 12 2 bp94amj.txt
# 24195 breb08jom.txt
# 5 10 1 breb08jom.txt
# 16154 brm11jbe.txt
# 4 9 1 brm11jbe.txt
# 14221 bs05jams.txt
# 5 15 3 bs05jams.txt
# 11254 bss03amj.txt
# 5 18 3 bss03amj.txt
# 21339 bvvs05jap.txt
# 5 13 2 bvvs05jap.txt
# 7500 bw04jbr.txt
# 5 18 4 bw04jbr.txt
# 7118 cdg07sjp.txt
# 5 19 4 cdg07sjp.txt
# 14150 ce98jom.txt
# 5 10 2 ce98jom.txt
# 12760 ces06ee.txt
# 5 9 1 ces06ee.txt
# 26850 cg01aaaj.txt
# 5 14 2 cg01aaaj.txt
# 14208 cg05smj.txt
# 4 6 1 cg05smj.txt
# 14560 chl08hrm.txt
# 5 9 1 chl08hrm.txt
# 11509 chl09ijhrm.txt
# 5 10 1 chl09ijhrm.txt
# 20866 ck99smj.txt
# 5 17 2 ck99smj.txt
# 14765 ckc10ajm.txt
# 5 16 3 ckc10ajm.txt
# 15448 cl09etp.txt
# 5 13 2 cl09etp.txt
# 23795 cl10pp.txt
# 5 12 2 cl10pp.txt
# 23841 clrv08aos.txt
# 5 17 2 clrv08aos.txt
# 7907 cls06jbe.txt
# 5 20 4 cls06jbe.txt
# 13875 clv11ijhrm.txt
# 5 15 2 clv11ijhrm.txt
# 6696 cm80ar.txt
# 5 19 3 cm80ar.txt
# 15448 cs06amj.txt
# 5 17 2 cs06amj.txt
# 12971 ct05crr.txt
# 5 15 2 ct05crr.txt
# 16540 ctsm08jem.txt
# 5 14 2 ctsm08jem.txt
# 12277 cw09smj.txt
# 4 8 1 cw09smj.txt
# 9017 cw84amj.txt
# 5 15 3 cw84amj.txt
# 15202 cww15ijpdlm.txt
# 5 13 2 cww15ijpdlm.txt
# 14902 cys14jcp.txt
# 5 13 2 cys14jcp.txt
# 15418 d00jom.txt
# 5 14 2 d00jom.txt
# 15448 d03jom.txt
# 5 12 2 d03jom.txt
# 20139 dc05jms.txt
# 5 14 2 dc05jms.txt
# 20439 dd96amj.txt
# 5 16 2 dd96amj.txt
# 15034 dhy00ms.txt
# 5 15 2 dhy00ms.txt
# 10827 dj01amj.txt
# 5 18 3 dj01amj.txt
# 8040 dtba07jap.txt
# 8 804 216 dtba07jap.txt
# 15832 dtkhb02sjweh.txt
# 5 18 2 dtkhb02sjweh.txt
# 19429 ekks05smj.txt
# 5 14 2 ekks05smj.txt
# 14189 fcwz15jcp.txt
# 5 14 2 fcwz15jcp.txt
# 14191 fo05jom.txt
# 4 6 1 fo05jom.txt
# 14913 fs90amj.txt
# 5 16 3 fs90amj.txt
# 25292 g01ilr.txt
# 5 14 2 g01ilr.txt
# 17291 g03ijhrm.txt
# 5 11 2 g03ijhrm.txt
# 23555 gac11ijtr.txt
# 4 7 1 gac11ijtr.txt
# 10105 gb04amj.txt
# 5 17 3 gb04amj.txt
# 11778 gi03pp.txt
# 5 11 2 gi03pp.txt
# 17419 gm90amj.txt
# 5 16 2 gm90amj.txt
# 13520 gmcs03bjir.txt
# 5 14 2 gmcs03bjir.txt
# 16306 gp01bjir.txt
# 5 12 2 gp01bjir.txt
# 7386 gw94amj.txt
# 5 15 3 gw94amj.txt
# 10706 gwde00jom.txt
# 5 15 2 gwde00jom.txt
# 20650 gwm11pp.txt
# 5 13 2 gwm11pp.txt
# 23102 h95amj.txt
# 6 15 2 h95amj.txt
# 17594 hm96aaaj.txt
# 5 12 2 hm96aaaj.txt
# 11547 hnn05ear.txt
# 5 17 3 hnn05ear.txt
# 9948 hw01ijaar.txt
# 5 14 2 hw01ijaar.txt
# 12731 jd98jms.txt
# 5 11 2 jd98jms.txt
# 18562 jk16jbe.txt
# 4 7 1 jk16jbe.txt
# 16128 jv04amj.txt
# 5 18 3 jv04amj.txt
# 24126 jy11bjir.txt
# 3 5 0 jy11bjir.txt
# 23889 k03jom.txt
# 5 14 2 k03jom.txt
# 10303 kavsc06amj.txt
# 5 15 3 kavsc06amj.txt
# 19703 kb06ijhrm.txt
# 5 15 2 kb06ijhrm.txt
# 12483 kevf03oem.txt
# 4 6 1 kevf03oem.txt
# 12504 kl02ms.txt
# 4 18 3 kl02ms.txt
# 21828 km00smj.txt
# 5 19 2 km00smj.txt
# 0 km96smj.txt
# Looks like a file with no words km96smj.txt
# 11934 kyr11ijsom.txt
# 6 14 2 kyr11ijsom.txt
# 11254 lat13imds.txt
# 6 9 1 lat13imds.txt
# 8064 lb98gjhr.txt
# 5 17 4 lb98gjhr.txt
# 10340 lcy12ijebm.txt
# 6 10 2 lcy12ijebm.txt
# 22788 lk09amj.txt
# 5 9 1 lk09amj.txt
# 580 lkc12imds.txt
# 6 14 6 lkc12imds.txt
# 9877 lm96os.txt
# 6 15 3 lm96os.txt
# 12857 lpaf13jcp.txt
# 5 15 3 lpaf13jcp.txt
# 8254 ltg13jcp.txt
# 5 12 2 ltg13jcp.txt
# 7837 lw98hrdq.txt
# 5 11 2 lw98hrdq.txt
# 17923 lwlm14amj.txt
# 5 20 3 lwlm14amj.txt
# 20693 m06aaaj.txt
# 5 17 2 m06aaaj.txt
# 13889 m10bse.txt
# 5 13 2 m10bse.txt
# 16683 mao10jbe.txt
# 5 23 4 mao10jbe.txt
# 10439 mfb09jbe.txt
# 4 11 2 mfb09jbe.txt
# 18920 ml01jom.txt
# 4 8 1 ml01jom.txt
# 9857 mo05jbr.txt
# 5 14 3 mo05jbr.txt
# 29876 mq13os.txt
# 4 14 2 mq13os.txt
# 23970 ms10jbe.txt
# 5 14 2 ms10jbe.txt
# 15329 ms96amj.txt
# 5 15 2 ms96amj.txt
# 11220 mss88amj.txt
# 5 12 2 mss88amj.txt
# 23976 mt09jms.txt
# 5 13 1 mt09jms.txt
# 13560 ntll98ijhrm.txt
# 5 15 2 ntll98ijhrm.txt
# 8375 nw09rqfa.txt
# 5 10 2 nw09rqfa.txt
# 10861 pb00amj.txt
# 5 19 3 pb00amj.txt
# 11048 pbf03jowb.txt
# 5 15 3 pbf03jowb.txt
# 18438 pl01smj.txt
# 5 15 2 pl01smj.txt
# 22229 ppr10amj.txt
# 5 14 2 ppr10amj.txt
# 20545 pwr09amj.txt
# 5 21 3 pwr09amj.txt
# 55739 r92aos.txt
# 2 6 0 r92aos.txt
# 15288 rbm09jbe.txt
# 5 16 3 rbm09jbe.txt
# 16672 rf97amj.txt
# 5 16 3 rf97amj.txt
# 15170 rffa98jom.txt
# 5 10 2 rffa98jom.txt
# 18923 s14isbj.txt
# 5 12 2 s14isbj.txt
# 16562 sc02amj.txt
# 5 16 2 sc02amj.txt
# 11857 sdjl05amj.txt
# 5 19 3 sdjl05amj.txt
# 16797 sgd05amj.txt
# 5 16 2 sgd05amj.txt
# 9664 sh11jop.txt
# 5 18 3 sh11jop.txt
# 11944 smfzmg06jech(Gazel Study).txt
# 5 14 2 smfzmg06jech(Gazel Study).txt
# 11944 smfzmg06jech(Whitehall II Study).txt
# 5 14 2 smfzmg06jech(Whitehall II Study).txt
# 9419 sn10csrem.txt
# 5 15 3 sn10csrem.txt
# 14435 snw07jom.txt
# 5 15 2 snw07jom.txt
# 11036 ss07etp.txt
# 5 7 1 ss07etp.txt
# 219 ss98jbe.txt
# 6 6 2 ss98jbe.txt
# 12851 sy04smj.txt
# 5 16 3 sy04smj.txt
# 18389 sz09amj.txt
# 5 17 2 sz09amj.txt
# 13056 szrgwdkd94mc.txt
# 6 15 3 szrgwdkd94mc.txt
# 0 t05ijhrm.txt
# Looks like a file with no words t05ijhrm.txt
# 9225 tbbc09halmstaduniversity.txt
# 6 8 1 tbbc09halmstaduniversity.txt
# 120 tg96amj.txt
# 5 4 0 tg96amj.txt
# 20355 th08os.txt
# 4 11 1 th08os.txt
# 9584 tlwt07jap.txt
# 7 564 135 tlwt07jap.txt
# 17262 tn08amj.txt
# 5 19 3 tn08amj.txt
# 13396 tr93pp.txt
# 5 8 1 tr93pp.txt
# 18966 tv05smj.txt
# 5 11 1 tv05smj.txt
# 7932 vfpbph09jap.txt
# 9 529 151 vfpbph09jap.txt
# 7301 vr87jom.txt
# 5 8 2 vr87jom.txt
# 10345 vt06mr.txt
# 5 11 2 vt06mr.txt
# 12423 w02jom.txt
# 5 17 2 w02jom.txt
# 21443 w05pp.txt
# 5 10 1 w05pp.txt
# 7774 w08csrem.txt
# 5 15 3 w08csrem.txt
# 65749 wa95amj.txt
# 3 6 0 wa95amj.txt
# 15483 wb93smj.txt
# 6 14 2 wb93smj.txt
# 13974 wg97smj.txt
# 5 20 3 wg97smj.txt
# 21158 wq11amj.txt
# 5 18 3 wq11amj.txt
# 12432 wqk10jbe.txt
# 4 12 2 wqk10jbe.txt
# 11538 x13bse.txt
# 5 16 3 x13bse.txt
# 10301 y07tqm.txt
# 4 15 3 y07tqm.txt
# 15514 zi06amj.txt
# 5 18 3 zi06amj.txt
# 14499 zmzttj11jcp.txt
# 5 14 2 zmzttj11jcp.txt
# 17784 zn02smj.txt
# 5 13 2 zn02smj.txt
# 15617 zsl14apjm.txt
# 5 15 2 zsl14apjm.txt

# %%
import nltk
for fileid in wordlists.fileids():
    news_text = wordlists.words(fileid)
    fdist = nltk.FreqDist(w.lower() for w in news_text)
    modals = ['can','could','would','might','will']
    print (fileid)
    for m in modals:
        
        print(m + ':',fdist[m], end = ' ')
    print ('\n')
# Out:
# a94amj.txt
# can: 12 could: 4 would: 3 might: 2 will: 13
#
# adg08hrm.txt
# can: 9 could: 1 would: 4 might: 0 will: 11
#
# afglmm10hrm.txt
# can: 16 could: 8 would: 9 might: 1 will: 9
#
# am79amj.txt
# can: 5 could: 0 would: 5 might: 1 will: 3
#
# ap81asq.txt
# can: 1 could: 3 would: 14 might: 10 will: 5
#
# ar78amj.txt
# can: 3 could: 0 would: 0 might: 0 will: 3
#
# atc05ijhrm.txt
# can: 13 could: 4 would: 3 might: 0 will: 9
#
# ay14ijbs.txt
# can: 15 could: 10 would: 5 might: 7 will: 12
#
# azw06meq.txt
# can: 17 could: 0 would: 6 might: 1 will: 20
#
# b04ilr.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# b99ilr.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# ba05joop.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# bb95jibs.txt
# can: 9 could: 1 would: 9 might: 7 will: 25
#
# bc11amj.txt
# can: 6 could: 7 would: 12 might: 1 will: 13
#
# bc15apjm.txt
# can: 18 could: 2 would: 3 might: 0 will: 2
#
# bgd05jom.txt
# can: 29 could: 1 would: 6 might: 2 will: 8
#
# bl00aeam.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# bl00amj.txt
# can: 7 could: 3 would: 15 might: 12 will: 7
#
# bm05jbe.txt
# can: 6 could: 1 would: 4 might: 3 will: 3
#
# bm72rm.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# bnk00jbr.txt
# can: 11 could: 13 would: 6 might: 12 will: 14
#
# bp04beer.txt
# can: 3 could: 1 would: 10 might: 0 will: 3
#
# bp06jms.txt
# can: 7 could: 2 would: 8 might: 0 will: 5
#
# bp94amj.txt
# can: 10 could: 0 would: 8 might: 1 will: 4
#
# breb08jom.txt
# can: 36 could: 2 would: 10 might: 2 will: 10
#
# brm11jbe.txt
# can: 0 could: 5 would: 5 might: 1 will: 2
#
# bs05jams.txt
# can: 20 could: 8 would: 12 might: 5 will: 11
#
# bss03amj.txt
# can: 14 could: 3 would: 5 might: 1 will: 15
#
# bvvs05jap.txt
# can: 10 could: 9 would: 20 might: 3 will: 13
#
# bw04jbr.txt
# can: 12 could: 2 would: 3 might: 0 will: 20
#
# cdg07sjp.txt
# can: 5 could: 2 would: 3 might: 1 will: 13
#
# ce98jom.txt
# can: 11 could: 3 would: 12 might: 0 will: 8
#
# ces06ee.txt
# can: 10 could: 2 would: 9 might: 0 will: 5
#
# cg01aaaj.txt
# can: 5 could: 5 would: 12 might: 4 will: 10
#
# cg05smj.txt
# can: 3 could: 0 would: 6 might: 0 will: 5
#
# chl08hrm.txt
# can: 8 could: 2 would: 5 might: 2 will: 19
#
# chl09ijhrm.txt
# can: 5 could: 2 would: 2 might: 1 will: 11
#
# ck99smj.txt
# can: 51 could: 12 would: 17 might: 4 will: 23
#
# ckc10ajm.txt
# can: 19 could: 4 would: 1 might: 1 will: 0
#
# cl09etp.txt
# can: 11 could: 4 would: 6 might: 2 will: 2
#
# cl10pp.txt
# can: 16 could: 10 would: 6 might: 10 will: 4
#
# clrv08aos.txt
# can: 9 could: 0 would: 4 might: 2 will: 18
#
# cls06jbe.txt
# can: 18 could: 1 would: 1 might: 0 will: 4
#
# clv11ijhrm.txt
# can: 22 could: 11 would: 6 might: 1 will: 8
#
# cm80ar.txt
# can: 17 could: 0 would: 5 might: 3 will: 4
#
# cs06amj.txt
# can: 12 could: 2 would: 6 might: 1 will: 16
#
# ct05crr.txt
# can: 2 could: 1 would: 5 might: 2 will: 7
#
# ctsm08jem.txt
# can: 7 could: 4 would: 8 might: 5 will: 9
#
# cw09smj.txt
# can: 13 could: 0 would: 1 might: 4 will: 6
#
# cw84amj.txt
# can: 12 could: 9 would: 7 might: 7 will: 15
#
# cww15ijpdlm.txt
# can: 15 could: 4 would: 5 might: 2 will: 3
#
# cys14jcp.txt
# can: 14 could: 8 would: 8 might: 2 will: 2
#
# d00jom.txt
# can: 15 could: 9 would: 3 might: 2 will: 1
#
# d03jom.txt
# can: 14 could: 7 would: 7 might: 4 will: 11
#
# dc05jms.txt
# can: 17 could: 17 would: 7 might: 4 will: 10
#
# dd96amj.txt
# can: 25 could: 2 would: 12 might: 1 will: 40
#
# dhy00ms.txt
# can: 21 could: 2 would: 6 might: 5 will: 8
#
# dj01amj.txt
# can: 6 could: 3 would: 4 might: 2 will: 3
#
# dtba07jap.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# dtkhb02sjweh.txt
# can: 18 could: 4 would: 17 might: 0 will: 13
#
# ekks05smj.txt
# can: 36 could: 5 would: 6 might: 16 will: 12
#
# fcwz15jcp.txt
# can: 18 could: 7 would: 1 might: 1 will: 12
#
# fo05jom.txt
# can: 10 could: 7 would: 4 might: 3 will: 46
#
# fs90amj.txt
# can: 12 could: 2 would: 11 might: 9 will: 5
#
# g01ilr.txt
# can: 39 could: 17 would: 15 might: 7 will: 1
#
# g03ijhrm.txt
# can: 8 could: 2 would: 13 might: 0 will: 13
#
# gac11ijtr.txt
# can: 16 could: 8 would: 4 might: 3 will: 19
#
# gb04amj.txt
# can: 23 could: 11 would: 20 might: 5 will: 7
#
# gi03pp.txt
# can: 14 could: 1 would: 7 might: 6 will: 0
#
# gm90amj.txt
# can: 6 could: 6 would: 20 might: 6 will: 11
#
# gmcs03bjir.txt
# can: 11 could: 0 would: 8 might: 7 will: 15
#
# gp01bjir.txt
# can: 18 could: 8 would: 13 might: 22 will: 19
#
# gw94amj.txt
# can: 4 could: 4 would: 5 might: 1 will: 9
#
# gwde00jom.txt
# can: 5 could: 5 would: 3 might: 2 will: 27
#
# gwm11pp.txt
# can: 16 could: 4 would: 11 might: 3 will: 25
#
# h95amj.txt
# can: 37 could: 4 would: 21 might: 3 will: 34
#
# hm96aaaj.txt
# can: 10 could: 4 would: 6 might: 4 will: 4
#
# hnn05ear.txt
# can: 7 could: 6 would: 6 might: 4 will: 12
#
# hw01ijaar.txt
# can: 11 could: 3 would: 5 might: 2 will: 6
#
# jd98jms.txt
# can: 14 could: 2 would: 14 might: 1 will: 14
#
# jk16jbe.txt
# can: 21 could: 1 would: 1 might: 1 will: 6
#
# jv04amj.txt
# can: 25 could: 3 would: 6 might: 16 will: 2
#
# jy11bjir.txt
# can: 6 could: 8 would: 3 might: 2 will: 4
#
# k03jom.txt
# can: 29 could: 1 would: 3 might: 2 will: 11
#
# kavsc06amj.txt
# can: 17 could: 2 would: 4 might: 0 will: 12
#
# kb06ijhrm.txt
# can: 13 could: 1 would: 5 might: 3 will: 14
#
# kevf03oem.txt
# can: 3 could: 7 would: 4 might: 0 will: 6
#
# kl02ms.txt
# can: 10 could: 3 would: 5 might: 4 will: 5
#
# km00smj.txt
# can: 60 could: 4 would: 14 might: 2 will: 10
#
# km96smj.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# kyr11ijsom.txt
# can: 10 could: 2 would: 1 might: 0 will: 9
#
# lat13imds.txt
# can: 21 could: 1 would: 5 might: 0 will: 7
#
# lb98gjhr.txt
# can: 5 could: 2 would: 3 might: 0 will: 1
#
# lcy12ijebm.txt
# can: 15 could: 3 would: 2 might: 1 will: 4
#
# lk09amj.txt
# can: 10 could: 1 would: 14 might: 11 will: 20
#
# lkc12imds.txt
# can: 0 could: 0 would: 0 might: 0 will: 1
#
# lm96os.txt
# can: 12 could: 1 would: 14 might: 4 will: 12
#
# lpaf13jcp.txt
# can: 17 could: 15 would: 1 might: 0 will: 4
#
# ltg13jcp.txt
# can: 13 could: 4 would: 1 might: 0 will: 7
#
# lw98hrdq.txt
# can: 20 could: 10 would: 12 might: 3 will: 11
#
# lwlm14amj.txt
# can: 15 could: 0 would: 7 might: 0 will: 3
#
# m06aaaj.txt
# can: 12 could: 12 would: 11 might: 5 will: 10
#
# m10bse.txt
# can: 6 could: 6 would: 9 might: 3 will: 3
#
# mao10jbe.txt
# can: 22 could: 5 would: 3 might: 1 will: 27
#
# mfb09jbe.txt
# can: 1 could: 2 would: 0 might: 0 will: 4
#
# ml01jom.txt
# can: 31 could: 1 would: 11 might: 3 will: 34
#
# mo05jbr.txt
# can: 8 could: 1 would: 1 might: 0 will: 35
#
# mq13os.txt
# can: 24 could: 4 would: 21 might: 3 will: 26
#
# ms10jbe.txt
# can: 19 could: 2 would: 0 might: 3 will: 9
#
# ms96amj.txt
# can: 30 could: 12 would: 16 might: 9 will: 33
#
# mss88amj.txt
# can: 5 could: 2 would: 5 might: 3 will: 3
#
# mt09jms.txt
# can: 24 could: 2 would: 3 might: 0 will: 13
#
# ntll98ijhrm.txt
# can: 14 could: 3 would: 19 might: 3 will: 29
#
# nw09rqfa.txt
# can: 4 could: 0 would: 0 might: 0 will: 1
#
# pb00amj.txt
# can: 13 could: 1 would: 0 might: 1 will: 7
#
# pbf03jowb.txt
# can: 8 could: 8 would: 15 might: 2 will: 1
#
# pl01smj.txt
# can: 13 could: 0 would: 4 might: 0 will: 3
#
# ppr10amj.txt
# can: 19 could: 11 would: 6 might: 2 will: 18
#
# pwr09amj.txt
# can: 12 could: 8 would: 10 might: 7 will: 23
#
# r92aos.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# rbm09jbe.txt
# can: 8 could: 5 would: 5 might: 2 will: 6
#
# rf97amj.txt
# can: 17 could: 10 would: 24 might: 6 will: 24
#
# rffa98jom.txt
# can: 19 could: 5 would: 8 might: 4 will: 0
#
# s14isbj.txt
# can: 7 could: 4 would: 9 might: 0 will: 13
#
# sc02amj.txt
# can: 9 could: 3 would: 9 might: 2 will: 28
#
# sdjl05amj.txt
# can: 10 could: 4 would: 10 might: 1 will: 4
#
# sgd05amj.txt
# can: 15 could: 5 would: 7 might: 2 will: 4
#
# sh11jop.txt
# can: 11 could: 3 would: 4 might: 1 will: 4
#
# smfzmg06jech(Gazel Study).txt
# can: 10 could: 5 would: 4 might: 2 will: 2
#
# smfzmg06jech(Whitehall II Study).txt
# can: 10 could: 5 would: 4 might: 2 will: 2
#
# sn10csrem.txt
# can: 14 could: 6 would: 1 might: 1 will: 9
#
# snw07jom.txt
# can: 8 could: 0 would: 7 might: 8 will: 4
#
# ss07etp.txt
# can: 7 could: 5 would: 13 might: 10 will: 9
#
# ss98jbe.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# sy04smj.txt
# can: 21 could: 2 would: 13 might: 3 will: 20
#
# sz09amj.txt
# can: 25 could: 7 would: 24 might: 8 will: 30
#
# szrgwdkd94mc.txt
# can: 6 could: 1 would: 1 might: 12 will: 16
#
# t05ijhrm.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# tbbc09halmstaduniversity.txt
# can: 8 could: 6 would: 0 might: 6 will: 1
#
# tg96amj.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
# th08os.txt
# can: 4 could: 1 would: 6 might: 4 will: 9
#
# tlwt07jap.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# tn08amj.txt
# can: 10 could: 9 would: 17 might: 7 will: 14
#
# tr93pp.txt
# can: 3 could: 4 would: 12 might: 18 will: 0
#
# tv05smj.txt
# can: 47 could: 5 would: 5 might: 1 will: 12
#
# vfpbph09jap.txt
# can: 0 could: 0 would: 0 might: 0 will: 0
#
# vr87jom.txt
# can: 13 could: 6 would: 3 might: 0 will: 2
#
# vt06mr.txt
# can: 4 could: 0 would: 3 might: 1 will: 0
#
# w02jom.txt
# can: 25 could: 3 would: 8 might: 0 will: 6
#
# w05pp.txt
# can: 21 could: 9 would: 14 might: 8 will: 8
#
# w08csrem.txt
# can: 19 could: 2 would: 1 might: 2 will: 12
#
# wa95amj.txt
# can: 0 could: 0 would: 0 might: 1 will: 0
#
# wb93smj.txt
# can: 14 could: 9 would: 12 might: 13 will: 27
#
# wg97smj.txt
# can: 17 could: 0 would: 13 might: 7 will: 7
#
# wq11amj.txt
# can: 25 could: 7 would: 9 might: 8 will: 9
#
# wqk10jbe.txt
# can: 7 could: 4 would: 1 might: 1 will: 5
#
# x13bse.txt
# can: 6 could: 6 would: 4 might: 0 will: 5
#
# y07tqm.txt
# can: 7 could: 0 would: 3 might: 0 will: 3
#
# zi06amj.txt
# can: 18 could: 6 would: 1 might: 0 will: 11
#
# zmzttj11jcp.txt
# can: 34 could: 13 would: 9 might: 1 will: 8
#
# zn02smj.txt
# can: 29 could: 1 would: 5 might: 6 will: 7
#
# zsl14apjm.txt
# can: 30 could: 3 would: 4 might: 5 will: 14
